# %%
# Para importar o DataQuality
import sys
import os
csv = "iphone.csv"
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(f"{csv}.ipynb"), '..')))

# Importando Classe DataQuality
from DataQuality import DataQuality

# %%
x = DataQuality(f"../data/{csv}")

# %%
x.relatorio()
# Out:
# ANÁLISE DO CONJUNTO DE DADOS DO DATAFRAME ../data/iphone.csv.
#
# INFORMAÇÕES GERAIS:
#
# Tamanho do Dataset:
# 3062 linhas;
# 11 colunas;
#               Colunas Tipo de Dados  Nulos Soma  Nulos %  Unicos Soma  \
# 0         productAsin        object           0     0.00            7
# 1             country        object           0     0.00            7
# 2                date        object           0     0.00          789
# 3          isVerified          bool           0     0.00            2
# 4         ratingScore         int64           0     0.00            5
# 5         reviewTitle        object           0     0.00         2018
# 6   reviewDescription        object          86     2.81         2297
# 7           reviewUrl        object          16     0.52         2460
# 8          reviewedIn        object           0     0.00         1255
# 9             variant        object           0     0.00           86
# 10        variantAsin        object           0     0.00           99
#
#     Unicos %
# 0       0.23
# 1       0.23
# 2      25.77
# 3       0.07
# 4       0.16
# 5      65.90
# 6      75.02
# 7      80.34
# 8      40.99
# 9       2.81
# 10      3.23
# Exibindo as 5 primeiras linhas:
#   productAsin country        date  isVerified  ratingScore  \
# 0  B09G9BL5CP   India  11-08-2024        True            4
# 1  B09G9BL5CP   India  16-08-2024        True            5
# 2  B09G9BL5CP   India  14-05-2024        True            4
# 3  B09G9BL5CP   India  24-06-2024        True            5
# 4  B09G9BL5CP   India  18-05-2024        True            5
#
#                reviewTitle                                  reviewDescription  \
# 0               No charger  Every thing is good about iPhones, there's not...
# 1          iPhone 13 256GB  It look so fabulous, I am android user switche...
# 2  Flip camera option nill  I tried to flip camera while recording but no ...
# 3                  Product                                       100% genuine
# 4             Good product         Happy to get the iPhone 13 in Amazon offer
#
#                                            reviewUrl  \
# 0  https://www.amazon.in/gp/customer-reviews/R345...
# 1  https://www.amazon.in/gp/customer-reviews/R2HJ...
# 2  https://www.amazon.in/gp/customer-reviews/R3Y7...
# 3  https://www.amazon.in/gp/customer-reviews/R1P9...
# 4  https://www.amazon.in/gp/customer-reviews/R1XI...
#
#                             reviewedIn                       variant  \
# 0  Reviewed in India on 11 August 2024  Colour: MidnightSize: 256 GB
# 1  Reviewed in India on 16 August 2024  Colour: MidnightSize: 256 GB
# 2     Reviewed in India on 14 May 2024  Colour: MidnightSize: 256 GB
# 3    Reviewed in India on 24 June 2024  Colour: MidnightSize: 256 GB
# 4     Reviewed in India on 18 May 2024  Colour: MidnightSize: 256 GB
#
#   variantAsin
# 0  B09G9BQS98
# 1  B09G9BQS98
# 2  B09G9BQS98
# 3  B09G9BQS98
# 4  B09G9BQS98
# Exibindo as 5 últimas linhas:
#      productAsin country        date  isVerified  ratingScore  \
# 3057  B09G9D8KRQ   India  11-10-2023        True            1
# 3058  B09G9D8KRQ   India  14-10-2022        True            2
# 3059  B09G9D8KRQ   India  24-02-2022        True            3
# 3060  B09G9D8KRQ   India  16-10-2023        True            1
# 3061  B09G9D8KRQ   India  11-11-2023        True            1
#
#                               reviewTitle  \
# 3057  Very bad experience with i phone 13
# 3058    not happy with this apple product
# 3059                           Good phone
# 3060                    Battery discharge
# 3061    Batter power needs to be improved
#
#                                       reviewDescription  \
# 3057  Useless phon never buy this heat n useless cam...
# 3058  iam not happy with this product why because ch...
# 3059                                         Good phone
# 3060  While charging mobile it's getting so hot even...
# 3061  Battery power is be very bad need to chat on d...
#
#                                               reviewUrl  \
# 3057  https://www.amazon.in/gp/customer-reviews/R10O...
# 3058  https://www.amazon.in/gp/customer-reviews/R2FW...
# 3059  https://www.amazon.in/gp/customer-reviews/R2C7...
# 3060  https://www.amazon.in/gp/customer-reviews/R3K0...
# 3061  https://www.amazon.in/gp/customer-reviews/R2QO...
#
#                                  reviewedIn  \
# 3057   Reviewed in India on 11 October 2023
# 3058   Reviewed in India on 14 October 2022
# 3059  Reviewed in India on 24 February 2022
# 3060   Reviewed in India on 16 October 2023
# 3061  Reviewed in India on 11 November 2023
#
#                                 variant variantAsin
# 3057  Colour: (PRODUCT) REDSize: 128 GB  B09G99CW2N
# 3058  Colour: (PRODUCT) REDSize: 128 GB  B09G99CW2N
# 3059  Colour: (PRODUCT) REDSize: 128 GB  B09G99CW2N
# 3060  Colour: (PRODUCT) REDSize: 128 GB  B09G99CW2N
# 3061  Colour: (PRODUCT) REDSize: 128 GB  B09G99CW2N
# Colunas duplicadas no Dataset:
#
# O Dataset não possui linhas duplicadas.
#
#
#
# INFORMAÇÕES DAS COLUNAS NUMÉRICAS.
#
# O Dataset possui as seguintes colunas numéricas: ['ratingScore'].
#
#
#
# Estatística descritiva das colunas numéricas:
#        ratingScore
# count  3062.000000
# mean      3.758981
# std       1.579033
# min       1.000000
# 25%       3.000000
# 50%       5.000000
# 75%       5.000000
# max       5.000000
# DISTRIBUIÇÃO DOS VALORES NUMÉRICOS:
#
# Análise da coluna 'ratingScore'
#    ratingScore  Soma      %
# 0            5  1604  52.38
# 1            1   587  19.17
# 2            4   461  15.06
# 3            3   239   7.81
# 4            2   171   5.58
# RELAÇÃO DE PARES DOS VALORES NUMÉRICOS:
# MATRIZ DE CORRELAÇÃO:
#
# Não foi possível fazer uma matriz de correlação.
#
#
#
# INFORMAÇÕES DAS COLUNAS CATEGÓRICAS.
#
# O Dataset possui as seguintes colunas categóricas: ['productAsin', 'country', 'date', 'isVerified', 'reviewTitle', 'reviewDescription', 'reviewUrl', 'reviewedIn', 'variant', 'variantAsin'].
#
#
#
# Maiores frequências das colunas categóricas:
#        productAsin country        date isVerified reviewTitle  \
# count         3062    3062        3062       3062        3062
# unique           7       7         789          2        2018
# top     B09G9D8KRQ   India  15-10-2023       True        Good
# freq           946    2229          17       2850         121
#
#        reviewDescription                                          reviewUrl  \
# count               2976                                               3046
# unique              2297                                               2460
# top                 Good  https://www.amazon.in/gp/customer-reviews/R2S1...
# freq                  32                                                  2
#
#                                    reviewedIn                   variant  \
# count                                    3062                      3062
# unique                                   1255                        86
# top     Reviewed in India on 13 November 2023  Colour: BlueSize: 128 GB
# freq                                       16                       300
#
#        variantAsin
# count         3062
# unique          99
# top     B09G9HD6PD
# freq           150
# DISTRIBUIÇÃO DOS VALORES CATEGÓRICOS:
#
# Análise da coluna 'productAsin'
#   productAsin  Soma      %
# 0  B09G9D8KRQ   946  30.89
# 1  B0BN72MLT2   594  19.40
# 2  B09G9BL5CP   587  19.17
# 3  B0BDK8LKPJ   431  14.08
# 4  B0CHX1W1XY   265   8.65
# 5  B09P82T3PZ   158   5.16
# 6  B09G9J5JZX    81   2.65
# Análise da coluna 'country'
#                 country  Soma      %
# 0                 India  2229  72.80
# 1         United States   579  18.91
# 2                 Japan   158   5.16
# 3  United Arab Emirates    80   2.61
# 4                Mexico    11   0.36
# 5                Canada     4   0.13
# 6                 Egypt     1   0.03
# Análise da coluna 'date'
#            date  Soma     %
# 0    15-10-2023    17  0.56
# 1    21-07-2024    17  0.56
# 2    12-10-2023    17  0.56
# 3    23-07-2024    16  0.52
# 4    13-11-2023    16  0.52
# ..          ...   ...   ...
# 784  27-05-2022     1  0.03
# 785  15-07-2022     1  0.03
# 786  16-06-2022     1  0.03
# 787  14-10-2022     1  0.03
# 788  24-02-2022     1  0.03
#
# [789 rows x 3 columns]
# A quantidade de valores únicos da coluna 'date' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'isVerified'
#    isVerified  Soma      %
# 0        True  2850  93.08
# 1       False   212   6.92
# Análise da coluna 'reviewTitle'
#                                      reviewTitle  Soma     %
# 0                                           Good   121  3.95
# 1                                      Excellent    32  1.05
# 2                                           Nice    29  0.95
# 3                                   Good product    27  0.88
# 4                                        Awesome    20  0.65
# ...                                          ...   ...   ...
# 2013           not happy with this apple product     1  0.03
# 2014                           It was the worst.     1  0.03
# 2015                Can be used without problems     1  0.03
# 2016  I was able to use it without any problems.     1  0.03
# 2017              Does it need to be up to date?     1  0.03
#
# [2018 rows x 3 columns]
# A quantidade de valores únicos da coluna 'reviewTitle' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'reviewDescription'
#                                       reviewDescription  Soma     %
# 0                                                  Good    32  1.05
# 1                                                  Nice    25  0.82
# 2                                          Good product    14  0.46
# 3                                     Excellent product    12  0.39
# 4                                             Excellent    10  0.33
# ...                                                 ...   ...   ...
# 2292  Improve your photo quality... Video is very im...     1  0.03
# 2293                                          Nic brand     1  0.03
# 2294  I have been tracking and comparing battery per...     1  0.03
# 2295  I purchased a refurbished iPhone 13, which is ...     1  0.03
# 2296  Its just 2 days and the device is overheating…...     1  0.03
#
# [2297 rows x 3 columns]
# A quantidade de valores únicos da coluna 'reviewDescription' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'reviewUrl'
#                                               reviewUrl  Soma     %
# 0     https://www.amazon.in/gp/customer-reviews/R2S1...     2  0.07
# 1     https://www.amazon.in/gp/customer-reviews/R2B0...     2  0.07
# 2     https://www.amazon.in/gp/customer-reviews/R1BZ...     2  0.07
# 3     https://www.amazon.in/gp/customer-reviews/RUT3...     2  0.07
# 4     https://www.amazon.in/gp/customer-reviews/R2WH...     2  0.07
# ...                                                 ...   ...   ...
# 2455  https://www.amazon.in/gp/customer-reviews/R371...     1  0.03
# 2456  https://www.amazon.in/gp/customer-reviews/RW40...     1  0.03
# 2457  https://www.amazon.in/gp/customer-reviews/R3R6...     1  0.03
# 2458  https://www.amazon.in/gp/customer-reviews/R198...     1  0.03
# 2459  https://www.amazon.in/gp/customer-reviews/R3T2...     1  0.03
#
# [2460 rows x 3 columns]
# A quantidade de valores únicos da coluna 'reviewUrl' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'reviewedIn'
#                                   reviewedIn  Soma     %
# 0      Reviewed in India on 13 November 2023    16  0.52
# 1       Reviewed in India on 15 October 2023    16  0.52
# 2       Reviewed in India on 12 October 2023    15  0.49
# 3     Reviewed in India on 25 September 2021    13  0.42
# 4          Reviewed in India on 23 July 2024    13  0.42
# ...                                      ...   ...   ...
# 1250     Reviewed in India on 1 January 2024     1  0.03
# 1251     Reviewed in India on 29 August 2024     1  0.03
# 1252   Reviewed in India on 27 February 2023     1  0.03
# 1253      Reviewed in India on 15 March 2023     1  0.03
# 1254      Reviewed in India on 5 August 2022     1  0.03
#
# [1255 rows x 3 columns]
# A quantidade de valores únicos da coluna 'reviewedIn' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'variant'
#                                               variant  Soma     %
# 0                            Colour: BlueSize: 128 GB   300  9.80
# 1                        Colour: MidnightSize: 128 GB   242  7.90
# 2                       Colour: StarlightSize: 128 GB   227  7.41
# 3                           Colour: GreenSize: 128 GB   188  6.14
# 4                            Colour: PinkSize: 128 GB   185  6.04
# ..                                                ...   ...   ...
# 81                       Colour: MidnightSize: 512 GB     1  0.03
# 82  Service Provider: VerizonColor: MidnightSize: ...     1  0.03
# 83  Service Provider: GSM CarriersColor: PurpleSiz...     1  0.03
# 84  Service Provider: GSM CarriersColor: BlueSize:...     1  0.03
# 85  Service Provider: T-MobileColor: MidnightSize:...     1  0.03
#
# [86 rows x 3 columns]
# A quantidade de valores únicos da coluna 'variant' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'variantAsin'
#    variantAsin  Soma     %
# 0   B09G9HD6PD   150  4.90
# 1   B09V4B6K53   150  4.90
# 2   B09G9FPGTN   150  4.90
# 3   B09G99CW2N   150  4.90
# 4   B09G9BL5CP   150  4.90
# ..         ...   ...   ...
# 94  B0BDJGX2XZ     1  0.03
# 95  B0BN71MQYZ     1  0.03
# 96  B0BN6Z2DKP     1  0.03
# 97  B0BN6ZKZY5     1  0.03
# 98  B0BN6ZWHYJ     1  0.03
#
# [99 rows x 3 columns]
# A quantidade de valores únicos da coluna 'variantAsin' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
