# %%
# Para importar o DataQuality
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("Testes.ipynb"), '..')))

# Importando Classe DataQuality
from DataQuality import DataQuality

# %%
x = DataQuality("../data/penguins.csv")

# %%
x.relatorio()
# Out:
# ANÁLISE DO CONJUNTO DE DADOS DO DATAFRAME ../data/penguins.csv.
#
# INFORMAÇÕES GERAIS:
#
# Tamanho do Dataset:
# 344 linhas;
# 7 colunas;
#              Colunas Tipo de Dados  Nulos Soma  Nulos %  Unicos Soma  Unicos %
# 0            species        object           0     0.00            3      0.87
# 1             island        object           0     0.00            3      0.87
# 2     bill_length_mm       float64           2     0.58          164     47.67
# 3      bill_depth_mm       float64           2     0.58           80     23.26
# 4  flipper_length_mm       float64           2     0.58           55     15.99
# 5        body_mass_g       float64           2     0.58           94     27.33
# 6                sex        object          11     3.20            2      0.58
# Colunas duplicadas no Dataset:
#
# O Dataset não possui linhas duplicadas.
#
#
#
# INFORMAÇÕES DAS COLUNAS NUMÉRICAS.
#
# O Dataset possui as seguintes colunas numéricas: ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g'].
#
#
#
# Estatística descritiva das colunas numéricas:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
# DISTRIBUIÇÃO DOS VALORES NUMÉRICOS:
#
# Análise da coluna 'bill_length_mm'
#      bill_length_mm  Soma     %
# 0              41.1     7  2.03
# 1              45.2     6  1.74
# 2              39.6     5  1.45
# 3              37.8     5  1.45
# 4              46.5     5  1.45
# ..              ...   ...   ...
# 159            41.7     1  0.29
# 160            53.4     1  0.29
# 161            55.1     1  0.29
# 162            48.8     1  0.29
# 163            49.9     1  0.29
#
# [164 rows x 3 columns]
# Análise da coluna 'bill_depth_mm'
#     bill_depth_mm  Soma     %
# 0            17.0    12  3.49
# 1            17.9    10  2.91
# 2            18.6    10  2.91
# 3            18.5    10  2.91
# 4            15.0    10  2.91
# ..            ...   ...   ...
# 75           13.2     1  0.29
# 76           13.6     1  0.29
# 77           13.1     1  0.29
# 78           13.3     1  0.29
# 79           14.9     1  0.29
#
# [80 rows x 3 columns]
# Análise da coluna 'flipper_length_mm'
#     flipper_length_mm  Soma     %
# 0               190.0    22  6.40
# 1               195.0    17  4.94
# 2               187.0    16  4.65
# 3               193.0    15  4.36
# 4               210.0    14  4.07
# 5               191.0    13  3.78
# 6               215.0    12  3.49
# 7               197.0    10  2.91
# 8               196.0    10  2.91
# 9               185.0     9  2.62
# 10              198.0     8  2.33
# 11              216.0     8  2.33
# 12              208.0     8  2.33
# 13              220.0     8  2.33
# 14              181.0     7  2.03
# 15              192.0     7  2.03
# 16              212.0     7  2.03
# 17              230.0     7  2.03
# 18              186.0     7  2.03
# 19              184.0     7  2.03
# 20              189.0     7  2.03
# 21              188.0     6  1.74
# 22              214.0     6  1.74
# 23              201.0     6  1.74
# 24              217.0     6  1.74
# 25              213.0     6  1.74
# 26              222.0     6  1.74
# 27              199.0     6  1.74
# 28              221.0     5  1.45
# 29              218.0     5  1.45
# 30              194.0     5  1.45
# 31              180.0     5  1.45
# 32              209.0     5  1.45
# 33              219.0     5  1.45
# 34              203.0     5  1.45
# 35              228.0     4  1.16
# 36              178.0     4  1.16
# 37              200.0     4  1.16
# 38              225.0     4  1.16
# 39              202.0     4  1.16
# 40              182.0     3  0.87
# 41              205.0     3  0.87
# 42              224.0     3  0.87
# 43              223.0     2  0.58
# 44              229.0     2  0.58
# 45              207.0     2  0.58
# 46              183.0     2  0.58
# 47              211.0     2  0.58
# 48              179.0     1  0.29
# 49              174.0     1  0.29
# 50              172.0     1  0.29
# 51              206.0     1  0.29
# 52              176.0     1  0.29
# 53              231.0     1  0.29
# 54              226.0     1  0.29
# Análise da coluna 'body_mass_g'
#     body_mass_g  Soma     %
# 0        3800.0    12  3.49
# 1        3700.0    11  3.20
# 2        3950.0    10  2.91
# 3        3900.0    10  2.91
# 4        3550.0     9  2.62
# ..          ...   ...   ...
# 89       5450.0     1  0.29
# 90       4975.0     1  0.29
# 91       4575.0     1  0.29
# 92       4375.0     1  0.29
# 93       5750.0     1  0.29
#
# [94 rows x 3 columns]
# RELAÇÃO DE PARES DOS VALORES NUMÉRICOS:
# MATRIZ DE CORRELAÇÃO:
# INFORMAÇÕES DAS COLUNAS CATEGÓRICAS.
#
# O Dataset possui as seguintes colunas categóricas: ['species', 'island', 'sex'].
#
#
#
# Maiores frequências das colunas categóricas:
#        species  island   sex
# count      344     344   333
# unique       3       3     2
# top     Adelie  Biscoe  MALE
# freq       152     168   168
# DISTRIBUIÇÃO DOS VALORES CATEGÓRICOS:
#
# Análise da coluna 'species'
#      species  Soma      %
# 0     Adelie   152  44.19
# 1     Gentoo   124  36.05
# 2  Chinstrap    68  19.77
# Análise da coluna 'island'
#       island  Soma      %
# 0     Biscoe   168  48.84
# 1      Dream   124  36.05
# 2  Torgersen    52  15.12
# Análise da coluna 'sex'
#       sex  Soma      %
# 0    MALE   168  48.84
# 1  FEMALE   165  47.97
