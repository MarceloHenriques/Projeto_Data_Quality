# %%
# Para importar o DataQuality
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("Testes.ipynb"), '..')))

# Importando Classe DataQuality
from DataQuality import DataQuality

# %%
x = DataQuality("../data/netflix_titles.csv")

# %%
x.relatorio()
# Out:
# ANÁLISE DO CONJUNTO DE DADOS DO DATAFRAME ../data/netflix_titles.csv.
#
# INFORMAÇÕES GERAIS:
#
# Tamanho do Dataset:
# 8807 linhas;
# 12 colunas;
#          Colunas Tipo de Dados  Nulos Soma  Nulos %  Unicos Soma  Unicos %
# 0        show_id        object           0     0.00         8807    100.00
# 1           type        object           0     0.00            2      0.02
# 2          title        object           0     0.00         8807    100.00
# 3       director        object        2634    29.91         4528     51.41
# 4           cast        object         825     9.37         7692     87.34
# 5        country        object         831     9.44          748      8.49
# 6     date_added        object          10     0.11         1767     20.06
# 7   release_year         int64           0     0.00           74      0.84
# 8         rating        object           4     0.05           17      0.19
# 9       duration        object           3     0.03          220      2.50
# 10     listed_in        object           0     0.00          514      5.84
# 11   description        object           0     0.00         8775     99.64
# Colunas duplicadas no Dataset:
#
# O Dataset não possui linhas duplicadas.
#
#
#
# INFORMAÇÕES DAS COLUNAS NUMÉRICAS.
#
# O Dataset possui as seguintes colunas numéricas: ['release_year'].
#
#
#
# Estatística descritiva das colunas numéricas:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000
# DISTRIBUIÇÃO DOS VALORES NUMÉRICOS:
#
# Análise da coluna 'release_year'
#     release_year  Soma      %
# 0           2018  1147  13.02
# 1           2017  1032  11.72
# 2           2019  1030  11.70
# 3           2020   953  10.82
# 4           2016   902  10.24
# ..           ...   ...    ...
# 69          1961     1   0.01
# 70          1925     1   0.01
# 71          1959     1   0.01
# 72          1966     1   0.01
# 73          1947     1   0.01
#
# [74 rows x 3 columns]
# RELAÇÃO DE PARES DOS VALORES NUMÉRICOS:
# MATRIZ DE CORRELAÇÃO:
#
# Não foi possível fazer uma matriz de correlação.
#
#
#
# INFORMAÇÕES DAS COLUNAS CATEGÓRICAS.
#
# O Dataset possui as seguintes colunas categóricas: ['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added', 'rating', 'duration', 'listed_in', 'description'].
#
#
#
# Maiores frequências das colunas categóricas:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8807           4528                7692
# top      s8807  Movie  Zubaan  Rajiv Chilaka  David Attenborough
# freq         1   6131       1             19                  19
#
#               country       date_added rating  duration  \
# count            7976             8797   8803      8804
# unique            748             1767     17       220
# top     United States  January 1, 2020  TV-MA  1 Season
# freq             2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# count                                                8807
# unique                                               8775
# top     Paranormal activity at a lush, abandoned prope...
# freq                                                    4
# DISTRIBUIÇÃO DOS VALORES CATEGÓRICOS:
#
# Análise da coluna 'show_id'
#      show_id  Soma     %
# 0      s8807     1  0.01
# 1         s1     1  0.01
# 2         s2     1  0.01
# 3         s3     1  0.01
# 4         s4     1  0.01
# ...      ...   ...   ...
# 8802     s11     1  0.01
# 8803     s12     1  0.01
# 8804     s13     1  0.01
# 8805     s14     1  0.01
# 8806     s15     1  0.01
#
# [8807 rows x 3 columns]
# A coluna 'show_id' possui apenas valores únicos.
#
# Análise da coluna 'type'
#       type  Soma      %
# 0    Movie  6131  69.62
# 1  TV Show  2676  30.38
# Análise da coluna 'title'
#                                     title  Soma     %
# 0                                  Zubaan     1  0.01
# 1                    Dick Johnson Is Dead     1  0.01
# 2                           Blood & Water     1  0.01
# 3                               Ganglands     1  0.01
# 4                   Jailbirds New Orleans     1  0.01
# ...                                   ...   ...   ...
# 8802  Vendetta: Truth, Lies and The Mafia     1  0.01
# 8803                     Bangkok Breaking     1  0.01
# 8804                         Je Suis Karl     1  0.01
# 8805     Confessions of an Invisible Girl     1  0.01
# 8806      Crime Stories: India Detectives     1  0.01
#
# [8807 rows x 3 columns]
# A coluna 'title' possui apenas valores únicos.
#
# Análise da coluna 'director'
#                      director  Soma     %
# 0               Rajiv Chilaka    19  0.22
# 1      Raúl Campos, Jan Suter    18  0.20
# 2                Marcus Raboy    16  0.18
# 3                 Suhas Kadav    16  0.18
# 4                   Jay Karas    14  0.16
# ...                       ...   ...   ...
# 4523                   Mu Chu     1  0.01
# 4524  Chandra Prakash Dwivedi     1  0.01
# 4525          Majid Al Ansari     1  0.01
# 4526             Peter Hewitt     1  0.01
# 4527             Paul Raschid     1  0.01
#
# [4528 rows x 3 columns]
# A quantidade de valores únicos da coluna 'director' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'cast'
#                                                    cast  Soma     %
# 0                                    David Attenborough    19  0.22
# 1     Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...    14  0.16
# 2                                           Samuel West    10  0.11
# 3                                           Jeff Dunham     7  0.08
# 4     Michela Luci, Jamie Watson, Eric Peterson, Ann...     6  0.07
# ...                                                 ...   ...   ...
# 7687  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...     1  0.01
# 7688  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...     1  0.01
# 7689  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...     1  0.01
# 7690  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...     1  0.01
# 7691  Logan Browning, Brandon P. Bell, DeRon Horton,...     1  0.01
#
# [7692 rows x 3 columns]
# A quantidade de valores únicos da coluna 'cast' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'country'
#                                            country  Soma      %
# 0                                    United States  2818  32.00
# 1                                            India   972  11.04
# 2                                   United Kingdom   419   4.76
# 3                                            Japan   245   2.78
# 4                                      South Korea   199   2.26
# ..                                             ...   ...    ...
# 743                                  Russia, Spain     1   0.01
# 744          Croatia, Slovenia, Serbia, Montenegro     1   0.01
# 745                                  Japan, Canada     1   0.01
# 746  United States, France, South Korea, Indonesia     1   0.01
# 747                   United Arab Emirates, Jordan     1   0.01
#
# [748 rows x 3 columns]
# A quantidade de valores únicos da coluna 'country' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'date_added'
#              date_added  Soma     %
# 0       January 1, 2020   109  1.24
# 1      November 1, 2019    89  1.01
# 2         March 1, 2018    75  0.85
# 3     December 31, 2019    74  0.84
# 4       October 1, 2018    71  0.81
# ...                 ...   ...   ...
# 1762      June 15, 2014     1  0.01
# 1763  November 18, 2017     1  0.01
# 1764   February 8, 2016     1  0.01
# 1765   October 21, 2018     1  0.01
# 1766       June 1, 2018     1  0.01
#
# [1767 rows x 3 columns]
# A quantidade de valores únicos da coluna 'date_added' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'rating'
#       rating  Soma      %
# 0      TV-MA  3207  36.41
# 1      TV-14  2160  24.53
# 2      TV-PG   863   9.80
# 3          R   799   9.07
# 4      PG-13   490   5.56
# 5      TV-Y7   334   3.79
# 6       TV-Y   307   3.49
# 7         PG   287   3.26
# 8       TV-G   220   2.50
# 9         NR    80   0.91
# 10         G    41   0.47
# 11  TV-Y7-FV     6   0.07
# 12     NC-17     3   0.03
# 13        UR     3   0.03
# 14    74 min     1   0.01
# 15    84 min     1   0.01
# 16    66 min     1   0.01
# Análise da coluna 'duration'
#       duration  Soma      %
# 0     1 Season  1793  20.36
# 1    2 Seasons   425   4.83
# 2    3 Seasons   199   2.26
# 3       90 min   152   1.73
# 4       97 min   146   1.66
# ..         ...   ...    ...
# 215    228 min     1   0.01
# 216     18 min     1   0.01
# 217    205 min     1   0.01
# 218    201 min     1   0.01
# 219    191 min     1   0.01
#
# [220 rows x 3 columns]
# A quantidade de valores únicos da coluna 'duration' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'listed_in'
#                                              listed_in  Soma     %
# 0                         Dramas, International Movies   362  4.11
# 1                                        Documentaries   359  4.08
# 2                                      Stand-Up Comedy   334  3.79
# 3               Comedies, Dramas, International Movies   274  3.11
# 4     Dramas, Independent Movies, International Movies   252  2.86
# ..                                                 ...   ...   ...
# 509         Classic & Cult TV, TV Horror, TV Mysteries     1  0.01
# 510   British TV Shows, TV Dramas, TV Sci-Fi & Fantasy     1  0.01
# 511  Action & Adventure, Faith & Spirituality, Sci-...     1  0.01
# 512               Comedies, Cult Movies, Sports Movies     1  0.01
# 513                     Cult Movies, Dramas, Thrillers     1  0.01
#
# [514 rows x 3 columns]
# A quantidade de valores únicos da coluna 'listed_in' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'description'
#                                             description  Soma     %
# 0     Paranormal activity at a lush, abandoned prope...     4  0.05
# 1     A surly septuagenarian gets another chance at ...     3  0.03
# 2     Multiple women report their husbands as missin...     3  0.03
# 3     Challenged to compose 100 songs before he can ...     3  0.03
# 4     As a woman scours Hyderabad for her missing hu...     2  0.02
# ...                                                 ...   ...   ...
# 8770  Two young lovers set out to overcome the obsta...     1  0.01
# 8771  The patriarch of a wealthy family with one ind...     1  0.01
# 8772  Up to his old tricks, con man Dharam poses as ...     1  0.01
# 8773  Thanks to an arranged marriage that was design...     1  0.01
# 8774  A scrappy but poor boy worms his way into a ty...     1  0.01
#
# [8775 rows x 3 columns]
# A quantidade de valores únicos da coluna 'description' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# c:\Users\nicol\OneDrive\Estudos\AdaTech\Santander Coders 2024\Projeto_04.03_DataViz\DataQuality.py:154: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
