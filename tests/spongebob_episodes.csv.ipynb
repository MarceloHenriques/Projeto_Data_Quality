# %%
# Para importar o DataQuality
import sys
import os
csv = "spongebob_episodes.csv"
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(f"{csv}.ipynb"), '..')))

# Importando Classe DataQuality
from DataQuality import DataQuality

# %%
x = DataQuality(f"../data/{csv}")

# %%
x.relatorio()
# Out:
# ANÁLISE DO CONJUNTO DE DADOS DO DATAFRAME ../data/spongebob_episodes.csv.
#
# INFORMAÇÕES GERAIS:
#
# Tamanho do Dataset:
# 583 linhas;
# 25 colunas;
#                     Colunas Tipo de Dados  Nulos Soma  Nulos %  Unicos Soma  \
# 0                   Airdate        object           0     0.00          393
# 1                 Animation        object          14     2.40           25
# 2      Animation Supervisor        object         581    99.66            1
# 3            Copyright year        object           0     0.00           26
# 4                  Creative        object         254    43.57            3
# 5                 Episode №        object           0     0.00          583
# 6                  Guest(s)        object         393    67.41          164
# 7             Line Producer        object         515    88.34            2
# 8                      Main        object         562    96.40            5
# 9                      Next        object           0     0.00          583
# 10                 Previous        object           1     0.17          582
# 11          Production code        object           0     0.00          582
# 12             Running time        object           0     0.00           99
# 13                 Season №         int64           0     0.00           14
# 14        Sister episode(s)        object          31     5.32          552
# 15               Storyboard        object         106    18.18           97
# 16     Storyboard Artist(s)        object         373    63.98           55
# 17              Supervising        object         355    60.89           20
# 18  Supervising Producer(s)        object         126    21.61            4
# 19                Technical        object         544    93.31            1
# 20  U.S. premiere time (ET)        object           1     0.17           72
# 21  U.S. viewers (millions)        object           1     0.17          290
# 22                Writer(s)        object           2     0.34          182
# 23               characters        object           0     0.00          583
# 24                    title        object           0     0.00          583
#
#     Unicos %
# 0      67.41
# 1       4.29
# 2       0.17
# 3       4.46
# 4       0.51
# 5     100.00
# 6      28.13
# 7       0.34
# 8       0.86
# 9     100.00
# 10     99.83
# 11     99.83
# 12     16.98
# 13      2.40
# 14     94.68
# 15     16.64
# 16      9.43
# 17      3.43
# 18      0.69
# 19      0.17
# 20     12.35
# 21     49.74
# 22     31.22
# 23    100.00
# 24    100.00
# Exibindo as 5 primeiras linhas:
#          Airdate                                   Animation  \
# 0      1997/1998                                  Alan Smart
# 1    May 1, 1999  ['Fred Miller', 'Tom Yasumi (uncredited)']
# 2    May 1, 1999                                  Tom Yasumi
# 3  July 17, 1999                                  Tom Yasumi
# 4  July 17, 1999                            Edgar Larrazábal
#
#   Animation Supervisor                                  Copyright year  \
# 0                  NaN  ['1997 (1997 version)', '1999 (1999 version)']
# 1                  NaN                                            1999
# 2                  NaN                                            1999
# 3                  NaN                                            1999
# 4                  NaN                                            1999
#
#                     Creative Episode №                         Guest(s)  \
# 0  Derek Drymon (uncredited)        1a                              NaN
# 1  Derek Drymon (uncredited)        1b                              NaN
# 2               Derek Drymon        1c                              NaN
# 3               Derek Drymon        2a                              NaN
# 4               Derek Drymon        2b  Jay Lender as Chef (uncredited)
#
#   Line Producer Main                   Next  ...                 Storyboard  \
# 0           NaN  NaN          "Reef Blower"  ...         Stephen Hillenburg
# 1           NaN  NaN  "Tea at the Treedome"  ...  Paul Tibbitt (uncredited)
# 2           NaN  NaN          "Bubblestand"  ...               Paul Tibbitt
# 3           NaN  NaN         "Ripped Pants"  ...             Ennio Torresan
# 4           NaN  NaN         "Jellyfishing"  ...               Paul Tibbitt
#
#       Storyboard Artist(s) Supervising  Supervising Producer(s) Technical  \
# 0             Derek Drymon         NaN                      NaN       NaN
# 1  Jay Lender (uncredited)         NaN                      NaN       NaN
# 2              Mark O'Hare         NaN                      NaN       NaN
# 3               Erik Wiese         NaN                      NaN       NaN
# 4              Mark O'Hare         NaN                      NaN       NaN
#
#   U.S. premiere time (ET) U.S. viewers (millions)  \
# 0                 9:30 pm                    2.96
# 1                 9:38 pm                    2.96
# 2                 9:45 pm                    2.96
# 3                10:00 am                    2.51
# 4                10:15 am                    2.51
#
#                                            Writer(s)  \
# 0  ['Stephen Hillenburg', 'Derek Drymon', 'Tim Hi...
# 1  ['Stephen Hillenburg', 'Derek Drymon', 'Tim Hi...
# 2   ['Peter Burns', 'Doug Lawrence', 'Paul Tibbitt']
# 3  ['Ennio Torresan', 'Erik Wiese', 'Stephen Hill...
# 4                    ['Paul Tibbitt', 'Peter Burns']
#
#                                           characters                title
# 0  French Narrator, Sea urchins, SpongeBob Square...          Help Wanted
# 1  SpongeBob SquarePants, Squidward Tentacles, Re...          Reef Blower
# 2  SpongeBob SquarePants, Jellyfish, Lavender jel...  Tea at the Treedome
# 3  SpongeBob SquarePants, Scallop, Squidward Tent...          Bubblestand
# 4  French Narrator, SpongeBob SquarePants, Sponge...         Ripped Pants
#
# [5 rows x 25 columns]
# Exibindo as 5 últimas linhas:
#               Airdate        Animation Animation Supervisor Copyright year  \
# 578     July 22, 2024              NaN                  NaN           2024
# 579     July 23, 2024  Andrew Overtoom                  NaN           2024
# 580     July 24, 2024  Andrew Overtoom                  NaN           2024
# 581     July 25, 2024   Michelle Bryan                  NaN           2024
# 582  October 29, 2024              NaN                  NaN           2024
#
#     Creative Episode №                            Guest(s) Line Producer Main  \
# 578      NaN      304a                                 NaN   Joe Crowley  NaN
# 579      NaN      304b                                 NaN   Joe Crowley  NaN
# 580      NaN      305a  Richard Ayoade as Sammy Suckerfish   Joe Crowley  NaN
# 581      NaN      305b                                 NaN   Joe Crowley  NaN
# 582      NaN       306                                 NaN   Joe Crowley  NaN
#
#                                     Next  ...       Storyboard  \
# 578                "Sheldon SquarePants"  ...  Benjamin Arcand
# 579                   "Sammy Suckerfish"  ...      Fred Osmond
# 580                     "Big League Bob"  ...       Dan Becker
# 581  "Snow Yellow and the Seven Jellies"  ...      Fred Osmond
# 582                             "UpWard"  ...              NaN
#
#     Storyboard Artist(s)      Supervising  \
# 578                  NaN      Ian Vazquez
# 579                  NaN  Dave Cunningham
# 580                  NaN  Dave Cunningham
# 581                  NaN      Sherm Cohen
# 582                  NaN              NaN
#
#                    Supervising Producer(s) Technical U.S. premiere time (ET)  \
# 578  ['Marc Ceccarelli', 'Vincent Waller']       NaN                 5:01 pm
# 579  ['Marc Ceccarelli', 'Vincent Waller']       NaN                 5:01 pm
# 580  ['Marc Ceccarelli', 'Vincent Waller']       NaN                 5:01 pm
# 581  ['Marc Ceccarelli', 'Vincent Waller']       NaN                 5:01 pm
# 582  ['Marc Ceccarelli', 'Vincent Waller']       NaN                     TBA
#
#     U.S. viewers (millions)        Writer(s)  \
# 578                     TBD  Luke Brookshier
# 579                     TBD   Andrew Goodman
# 580                     TBD    Doug Lawrence
# 581                     TBD              Kaz
# 582                     TBD              NaN
#
#                                             characters  \
# 578  SpongeBob SquarePants, Patrick Star, Squidward...
# 579  SpongeBob SquarePants, Sheldon J. Plankton, Ma...
# 580  SpongeBob SquarePants, Sammy Suckerfish, Sheld...
# 581  SpongeBob SquarePants, Patrick Star, Squidward...
# 582   SpongeBob SquarePants, Jellyfish, Karen Plankton
#
#                                  title
# 578              The Dirty Bubble Bass
# 579                Sheldon SquarePants
# 580                   Sammy Suckerfish
# 581                     Big League Bob
# 582  Snow Yellow and the Seven Jellies
#
# [5 rows x 25 columns]
# Colunas duplicadas no Dataset:
#
# O Dataset não possui linhas duplicadas.
#
#
#
# INFORMAÇÕES DAS COLUNAS NUMÉRICAS.
#
# O Dataset possui as seguintes colunas numéricas: ['Season №'].
#
#
#
# Estatística descritiva das colunas numéricas:
#          Season №
# count  583.000000
# mean     7.488851
# std      3.898999
# min      1.000000
# 25%      4.000000
# 50%      7.000000
# 75%     11.000000
# max     14.000000
# DISTRIBUIÇÃO DOS VALORES NUMÉRICOS:
#
# Análise da coluna 'Season №'
#     Season №  Soma     %
# 0         13    52  8.92
# 1          7    50  8.58
# 2         11    50  8.58
# 3          9    49  8.40
# 4         12    48  8.23
# 5          6    47  8.06
# 6          8    47  8.06
# 7          1    41  7.03
# 8          5    41  7.03
# 9          2    39  6.69
# 10         4    38  6.52
# 11         3    37  6.35
# 12        10    22  3.77
# 13        14    22  3.77
# RELAÇÃO DE PARES DOS VALORES NUMÉRICOS:
# MATRIZ DE CORRELAÇÃO:
#
# Não foi possível fazer uma matriz de correlação.
#
#
#
# INFORMAÇÕES DAS COLUNAS CATEGÓRICAS.
#
# O Dataset possui as seguintes colunas categóricas: ['Airdate', 'Animation', 'Animation Supervisor', 'Copyright year', 'Creative', 'Episode №', 'Guest(s)', 'Line Producer', 'Main', 'Next', 'Previous', 'Production code', 'Running time', 'Sister episode(s)', 'Storyboard', 'Storyboard Artist(s)', 'Supervising', 'Supervising Producer(s)', 'Technical', 'U.S. premiere time (ET)', 'U.S. viewers (millions)', 'Writer(s)', 'characters', 'title'].
#
#
#
# Maiores frequências das colunas categóricas:
#               Airdate   Animation  Animation Supervisor Copyright year  \
# count             583         569                     2            583
# unique            393          25                     1             26
# top     July 19, 2009  Tom Yasumi  Christopher Finnegan           2006
# freq                8         141                     2             39
#
#               Creative Episode №                               Guest(s)  \
# count              329       583                                    190
# unique               3       583                                    164
# top     Vincent Waller       306  Brian Doyle-Murray as Flying Dutchman
# freq               212         1                                      9
#
#        Line Producer                            Main      Next  ...  \
# count             68                              21       583  ...
# unique             2                               5       583  ...
# top      Joe Crowley  ['Walt Dohrn', 'Paul Tibbitt']  "UpWard"  ...
# freq              66                               7         1  ...
#
#                                 Storyboard Storyboard Artist(s)  Supervising  \
# count                                  477                  210          228
# unique                                  97                   55           20
# top     ['Casey Alexander', 'Zeus Cervas']          Fred Osmond  Sherm Cohen
# freq                                    65                   28           75
#
#        Supervising Producer(s)       Technical U.S. premiere time (ET)  \
# count                      457              39                     582
# unique                       4               1                      72
# top               Paul Tibbitt  Vincent Waller                 8:00 pm
# freq                       242              39                      67
#
#        U.S. viewers (millions) Writer(s)  \
# count                      582       581
# unique                     290       182
# top                        TBD       Kaz
# freq                        11        45
#
#                                               characters  \
# count                                                583
# unique                                               583
# top     SpongeBob SquarePants, Jellyfish, Karen Plankton
# freq                                                   1
#
#                                     title
# count                                 583
# unique                                583
# top     Snow Yellow and the Seven Jellies
# freq                                    1
#
# [4 rows x 24 columns]
# DISTRIBUIÇÃO DOS VALORES CATEGÓRICOS:
#
# Análise da coluna 'Airdate'
#                Airdate  Soma     %
# 0        July 19, 2009     8  1.37
# 1         June 5, 2007     7  1.20
# 2    November 28, 2008     7  1.20
# 3    February 18, 2010     6  1.03
# 4    November 16, 2010     6  1.03
# ..                 ...   ...   ...
# 388      July 22, 2024     1  0.17
# 389      July 23, 2024     1  0.17
# 390      July 24, 2024     1  0.17
# 391      July 25, 2024     1  0.17
# 392   October 29, 2024     1  0.17
#
# [393 rows x 3 columns]
# A quantidade de valores únicos da coluna 'Airdate' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'Animation'
#                                             Animation  Soma      %
# 0                                          Tom Yasumi   141  24.19
# 1                                          Alan Smart   121  20.75
# 2                                     Andrew Overtoom   119  20.41
# 3                        ['Alan Smart', 'Tom Yasumi']    46   7.89
# 4                                      Michelle Bryan    30   5.15
# 5                                        Sean Dempsey    28   4.80
# 6                                          Bob Jaques    22   3.77
# 7                                         Frank Weiss    13   2.23
# 8                                    Edgar Larrazábal    13   2.23
# 9                                         Fred Miller     9   1.54
# 10                  ['Andrew Overtoom', 'Tom Yasumi']     6   1.03
# 11                                   Larry Leichliter     3   0.51
# 12                   ['Michelle Bryan', 'Alan Smart']     3   0.51
# 13              ['Michelle Bryan', 'Andrew Overtoom']     2   0.34
# 14                  ['Andrew Overtoom', 'Alan Smart']     2   0.34
# 15     ['Michelle Bryan', 'Alan Smart', 'Tom Yasumi']     2   0.34
# 16         ['Fred Miller', 'Tom Yasumi (uncredited)']     1   0.17
# 17           ['Larry Leichliter', 'Leonard Robinson']     1   0.17
# 18    ['Andrew Overtoom', 'Alan Smart', 'Tom Yasumi']     1   0.17
# 19  ['Tom Yasumi', 'Andrew Overtoom (initially or ...     1   0.17
# 20  ['Alan Smart (also the scene timer for the liv...     1   0.17
# 21    ['Alan Smart', 'Andrew Overtoom', 'Tom Yasumi']     1   0.17
# 22                   ['Michelle Bryan', 'Tom Yasumi']     1   0.17
# 23                       Andrew Overtoom (uncredited)     1   0.17
# 24                    ['Alex Conaway', 'Jordy Judge']     1   0.17
# A quantidade de valores únicos da coluna 'Animation' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'Animation Supervisor'
#    Animation Supervisor  Soma     %
# 0  Christopher Finnegan     2  0.34
# A coluna 'Animation Supervisor' possui apenas valores únicos.
#
# Análise da coluna 'Copyright year'
#                                     Copyright year  Soma     %
# 0                                             2006    39  6.69
# 1                                             2018    37  6.35
# 2                                             2010    36  6.17
# 3                                             2017    33  5.66
# 4                                             2008    33  5.66
# 5                                             2023    32  5.49
# 6                                             2000    31  5.32
# 7                                             2012    31  5.32
# 8                                             2019    31  5.32
# 9                                             1999    30  5.15
# 10                                            2009    28  4.80
# 11                                            2001    28  4.80
# 12                                            2016    27  4.63
# 13                                            2011    27  4.63
# 14                                            2007    27  4.63
# 15                                            2002    23  3.95
# 16                                            2022    17  2.92
# 17                                            2024    16  2.74
# 18                                            2005    13  2.23
# 19                                            2020    11  1.89
# 20                                            2015    10  1.72
# 21                                            2013     9  1.54
# 22                                            2021     7  1.20
# 23                                    2001[note 1]     4  0.69
# 24                                    2019[note 1]     2  0.34
# 25  ['1997 (1997 version)', '1999 (1999 version)']     1  0.17
# A quantidade de valores únicos da coluna 'Copyright year' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'Creative'
#                     Creative  Soma      %
# 0             Vincent Waller   212  36.36
# 1               Derek Drymon   115  19.73
# 2  Derek Drymon (uncredited)     2   0.34
# Análise da coluna 'Episode №'
#     Episode №  Soma     %
# 0         306     1  0.17
# 1          1a     1  0.17
# 2          1b     1  0.17
# 3          1c     1  0.17
# 4          2a     1  0.17
# ..        ...   ...   ...
# 578        5b     1  0.17
# 579        6a     1  0.17
# 580        6b     1  0.17
# 581        7a     1  0.17
# 582        7b     1  0.17
#
# [583 rows x 3 columns]
# A coluna 'Episode №' possui apenas valores únicos.
#
# Análise da coluna 'Guest(s)'
#                                               Guest(s)  Soma     %
# 0                Brian Doyle-Murray as Flying Dutchman     9  1.54
# 1                 Sirena Irwin as Margaret SquarePants     4  0.69
# 2                   Marion Ross as Grandma SquarePants     4  0.69
# 3                          Alexander Ward as Nosferatu     4  0.69
# 4    ['Ernest Borgnine as Mermaid Man', 'Tim Conway...     3  0.51
# ..                                                 ...   ...   ...
# 159  ['Gary Anthony Williams as Goofy Manager/The G...     1  0.17
# 160          Brian Doyle-Murray as the Flying Dutchman     1  0.17
# 161  ['Malcolm McDowell as Percival Rockhound', 'Ke...     1  0.17
# 162                        Rosie Perez as Suzie Groove     1  0.17
# 163                 Richard Ayoade as Sammy Suckerfish     1  0.17
#
# [164 rows x 3 columns]
# A quantidade de valores únicos da coluna 'Guest(s)' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'Line Producer'
#       Line Producer  Soma      %
# 0       Joe Crowley    66  11.32
# 1  Donna Castricone     2   0.34
# Análise da coluna 'Main'
#                                  Main  Soma     %
# 0      ['Walt Dohrn', 'Paul Tibbitt']     7  1.20
# 1                      Aaron Springer     6  1.03
# 2      ['Paul Tibbitt', 'Walt Dohrn']     5  0.86
# 3  ['Mark Caballero', 'Seamus Walsh']     2  0.34
# 4                   Jonas Morganstein     1  0.17
# Análise da coluna 'Next'
#                                Next  Soma     %
# 0                          "UpWard"     1  0.17
# 1                     "Reef Blower"     1  0.17
# 2             "Tea at the Treedome"     1  0.17
# 3                     "Bubblestand"     1  0.17
# 4                    "Ripped Pants"     1  0.17
# ..                              ...   ...   ...
# 578  "Mermaid Man and Barnacle Boy"     1  0.17
# 579                       "Pickles"     1  0.17
# 580                  "Hall Monitor"     1  0.17
# 581                 "Jellyfish Jam"     1  0.17
# 582                "Sandy's Rocket"     1  0.17
#
# [583 rows x 3 columns]
# A coluna 'Next' possui apenas valores únicos.
#
# Análise da coluna 'Previous'
#                            Previous  Soma     %
# 0                  "Big League Bob"     1  0.17
# 1                     "Help Wanted"     1  0.17
# 2                     "Reef Blower"     1  0.17
# 3             "Tea at the Treedome"     1  0.17
# 4                     "Bubblestand"     1  0.17
# ..                              ...   ...   ...
# 577                "Pizza Delivery"     1  0.17
# 578          "Home Sweet Pineapple"     1  0.17
# 579  "Mermaid Man and Barnacle Boy"     1  0.17
# 580                       "Pickles"     1  0.17
# 581                  "Hall Monitor"     1  0.17
#
# [582 rows x 3 columns]
# A coluna 'Previous' possui apenas valores únicos.
#
# Análise da coluna 'Production code'
#                  Production code  Soma     %
# 0    325-1324[note 1]553[note 2]     2  0.34
# 1                       2515-140     1  0.17
# 2                       325-1350     1  0.17
# 3                       325-1342     1  0.17
# 4                       2515-108     1  0.17
# ..                           ...   ...   ...
# 577                     325-1423     1  0.17
# 578                     325-1424     1  0.17
# 579                     325-1427     1  0.17
# 580                     325-1428     1  0.17
# 581                     2515-103     1  0.17
#
# [582 rows x 3 columns]
# A quantidade de valores únicos da coluna 'Production code' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'Running time'
#               Running time  Soma      %
# 0               11 minutes   202  34.65
# 1   10 minutes, 59 seconds    30   5.15
# 2     11 minutes, 1 second    28   4.80
# 3   10 minutes, 58 seconds    25   4.29
# 4   10 minutes, 52 seconds    21   3.60
# ..                     ...   ...    ...
# 94  10 minutes, 16 seconds     1   0.17
# 95  14 minutes, 43 seconds     1   0.17
# 96   7 minutes, 10 seconds     1   0.17
# 97              44 minutes     1   0.17
# 98                     TBA     1   0.17
#
# [99 rows x 3 columns]
# A quantidade de valores únicos da coluna 'Running time' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'Sister episode(s)'
#                               Sister episode(s)  Soma     %
# 0                            "Sammy Suckerfish"     1  0.17
# 1    ['"Reef Blower"', '"Tea at the Treedome"']     1  0.17
# 2    ['"Help Wanted"', '"Tea at the Treedome"']     1  0.17
# 3            ['"Help Wanted"', '"Reef Blower"']     1  0.17
# 4                                "Ripped Pants"     1  0.17
# ..                                          ...   ...   ...
# 547                                   "Pickles"     1  0.17
# 548              "Mermaid Man and Barnacle Boy"     1  0.17
# 549                             "Jellyfish Jam"     1  0.17
# 550                              "Hall Monitor"     1  0.17
# 551                             "Squeaky Boots"     1  0.17
#
# [552 rows x 3 columns]
# A coluna 'Sister episode(s)' possui apenas valores únicos.
#
# Análise da coluna 'Storyboard'
#                                            Storyboard  Soma      %
# 0                  ['Casey Alexander', 'Zeus Cervas']    65  11.15
# 1                                      Aaron Springer    49   8.40
# 2                    ['Luke Brookshier', 'Nate Cash']    35   6.00
# 3                                         Fred Osmond    23   3.95
# 4                     ['Luke Brookshier', 'Tom King']    19   3.26
# ..                                                ...   ...    ...
# 92                           Fred Osmond (uncredited)     1   0.17
# 93                                    Eddie Trigueros     1   0.17
# 94  ['Fred Osmond', 'Dan Becker (uncredited middle...     1   0.17
# 95                     ['Zeus Cervas', 'Fred Osmond']     1   0.17
# 96                                        Ryan Kramer     1   0.17
#
# [97 rows x 3 columns]
# A quantidade de valores únicos da coluna 'Storyboard' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'Storyboard Artist(s)'
#                                  Storyboard Artist(s)  Soma     %
# 0                                         Fred Osmond    28  4.80
# 1                                        John Trabbic    23  3.95
# 2                                       Brian Morante    19  3.26
# 3                                     C.H. Greenblatt    11  1.89
# 4                                          Erik Wiese    10  1.72
# 5                                     Kelly Armstrong     9  1.54
# 6                                        Caleb Meurer     8  1.37
# 7    ['Carson Kugler', 'William Reiss', 'Erik Wiese']     8  1.37
# 8     ['Carson Kugler', 'William Reiss', 'Mike Roth']     7  1.20
# 9                                      Aaron Springer     6  1.03
# 10                                         Jay Lender     6  1.03
# 11                                        Mark O'Hare     6  1.03
# 12                                      William Reiss     5  0.86
# 13  ['Carson Kugler', 'Caleb Meurer', 'William Rei...     4  0.69
# 14                                       Lynne Naylor     4  0.69
# 15  ['Chuck Klein', 'Carson Kugler', 'Caleb Meurer...     3  0.51
# 16                                     Vincent Waller     3  0.51
# 17                                     Chris Mitchell     3  0.51
# 18                                        Zeus Cervas     3  0.51
# 19  ['Jay Lender (uncredited)', 'Dan Povenmire (un...     2  0.34
# 20                                          Chong Lee     2  0.34
# 21                                           Bob Camp     2  0.34
# 22            ['Paul Tibbitt', 'Ennio Torresan, Jr.']     2  0.34
# 23                                        Chuck Klein     2  0.34
# 24                                          Mike Roth     2  0.34
# 25                   ['Chris Allison', 'Ryan Kramer']     2  0.34
# 26                                    Shellie O'Brien     2  0.34
# 27  ['C.H. Greenblatt', 'Ennio Torresan (American ...     1  0.17
# 28   ['Carson Kugler', 'Erik Wiese', 'William Reiss']     1  0.17
# 29                                         Bill Reiss     1  0.17
# 30                   ['William Reiss', 'Chuck Klein']     1  0.17
# 31                            Jay Lender (uncredited)     1  0.17
# 32                                       Derek Drymon     1  0.17
# 33                   ['Chris Mitchell', 'Jay Lender']     1  0.17
# 34    ['C.H. Greenblatt', 'Zeus Cervas (uncredited)']     1  0.17
# 35                  ['C.H. Greenblatt', 'Erik Wiese']     1  0.17
# 36  ["Mark O'Hare", 'Ennio Torresan, Jr.', 'Erik W...     1  0.17
# 37  ['Paul Tibbitt (uncredited)', 'Ennio Torresan ...     1  0.17
# 38                  ['Heather Martinez', 'Mike Roth']     1  0.17
# 39  ['Zeus Cervas', 'Garrett Ho', 'Brad Vandergrif...     1  0.17
# 40                 ['Brad Vandergrift', 'Erik Wiese']     1  0.17
# 41                ['Zeus Cervas', 'Brad Vandergrift']     1  0.17
# 42  ['Zeus Cervas', 'Chuck Klein', 'Carson Kugler'...     1  0.17
# 43   ['Caleb Meurer', 'C.H. Greenblatt (uncredited)']     1  0.17
# 44  ['Zeus Cervas', 'Carson Kugler', 'Caleb Meurer...     1  0.17
# 45  ['Caleb Meurer', 'Carson Kugler', 'William Rei...     1  0.17
# 46  ['Carson Kugler', 'Heather Martinez', 'William...     1  0.17
# 47                  ['Caleb Meurer', 'Carson Kugler']     1  0.17
# 48                                        Howie Perry     1  0.17
# 49                 ['Casey Alexander', 'Zeus Cervas']     1  0.17
# 50                                       Joe Wierenga     1  0.17
# 51    ['Fred Osmond', 'Marc Ceccarelli (uncredited)']     1  0.17
# 52                                           Ed Baker     1  0.17
# 53              ['Brian Morante', 'Sally Cruikshank']     1  0.17
# 54                                   Kristen Morrison     1  0.17
# A quantidade de valores únicos da coluna 'Storyboard Artist(s)' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'Supervising'
#                                           Supervising  Soma      %
# 0                                         Sherm Cohen    75  12.86
# 1                                     Dave Cunningham    73  12.52
# 2                                        Adam Paloian    36   6.17
# 3                                         Ian Vazquez    18   3.09
# 4                                          Alan Smart     7   1.20
# 5   ['Marc Ceccarelli', 'Vincent Waller (uncredite...     4   0.69
# 6                  ['Sherm Cohen', 'Dave Cunningham']     2   0.34
# 7                 ['Dave Cunningham', 'Adam Paloian']     1   0.17
# 8                     ['Adam Paloian', 'Sherm Cohen']     1   0.17
# 9   ['Marc Ceccarelli (uncredited)', 'Vincent Wall...     1   0.17
# 10       ['Sherm Cohen', 'Adam Paloian (uncredited)']     1   0.17
# 11  ['Sherm Cohen', 'Dave Cunningham', 'Adam Paloi...     1   0.17
# 12                                           Bob Camp     1   0.17
# 13                       Marc Ceccarelli (uncredited)     1   0.17
# 14  ['Vincent Waller (uncredited)', 'Dave Cunningh...     1   0.17
# 15                           Sherm Cohen (uncredited)     1   0.17
# 16                                    Benjamin Arcand     1   0.17
# 17                 ['Dave Cunningham', 'Ian Vazquez']     1   0.17
# 18                     ['Sherm Cohen', 'Ian Vazquez']     1   0.17
# 19  ['Dave Cunningham', 'Sherm Cohen', 'Ian Vazquez']     1   0.17
# Análise da coluna 'Supervising Producer(s)'
#                              Supervising Producer(s)  Soma      %
# 0                                       Paul Tibbitt   242  41.51
# 1              ['Marc Ceccarelli', 'Vincent Waller']   196  33.62
# 2  ['Marc Ceccarelli', 'Jennie Monica', 'Vincent ...    15   2.57
# 3                                      Jennie Monica     4   0.69
# Análise da coluna 'Technical'
#         Technical  Soma     %
# 0  Vincent Waller    39  6.69
# A coluna 'Technical' possui apenas valores únicos.
#
# Análise da coluna 'U.S. premiere time (ET)'
#                               U.S. premiere time (ET)  Soma      %
# 0                                             8:00 pm    67  11.49
# 1                                             5:00 pm    54   9.26
# 2                                             8:15 pm    46   7.89
# 3                                             7:00 pm    41   7.03
# 4                                            10:00 am    34   5.83
# ..                                                ...   ...    ...
# 67   ['4:00 pm (Nicktoons)', '4:06 pm (Nickelodeon)']     1   0.17
# 68  ['3:45 pm (Nicktoons) (accidental)', '4:00 pm ...     1   0.17
# 69  ['2:27 pm (Nicktoons) (accidental)', '5:01 pm ...     1   0.17
# 70                                            5:16 pm     1   0.17
# 71                                                TBA     1   0.17
#
# [72 rows x 3 columns]
# A quantidade de valores únicos da coluna 'U.S. premiere time (ET)' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'U.S. viewers (millions)'
#     U.S. viewers (millions)  Soma     %
# 0                       TBD    11  1.89
# 1                      2.27     7  1.20
# 2                      3.65     6  1.03
# 3                      3.91     5  0.86
# 4                      2.85     5  0.86
# ..                      ...   ...   ...
# 285   ['1.43', 'N/A (cut)']     1  0.17
# 286                    1.43     1  0.17
# 287                    0.34     1  0.17
# 288                    0.16     1  0.17
# 289                    0.17     1  0.17
#
# [290 rows x 3 columns]
# A quantidade de valores únicos da coluna 'U.S. viewers (millions)' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'Writer(s)'
#                                              Writer(s)  Soma     %
# 0                                                  Kaz    45  7.72
# 1                                        Doug Lawrence    43  7.38
# 2                                       Andrew Goodman    32  5.49
# 3                                      Luke Brookshier    30  5.15
# 4                                           Ben Gruber    15  2.57
# ..                                                 ...   ...   ...
# 177  ['Kaz', 'Vincent Waller (additional writing)',...     1  0.17
# 178  ['Andrew Goodman', 'Benjamin Arcand (uncredite...     1  0.17
# 179     ['John Trabbic (uncredited)', 'Doug Lawrence']     1  0.17
# 180    ['Andrew Goodman', 'Adam Paloian (uncredited)']     1  0.17
# 181  ['Benjamin Arcand (uncredited)', 'Luke Brooksh...     1  0.17
#
# [182 rows x 3 columns]
# A quantidade de valores únicos da coluna 'Writer(s)' é muito grande.
# Serão exibidos os 20 valores mais relevantes.
# Análise da coluna 'characters'
#                                             characters  Soma     %
# 0     SpongeBob SquarePants, Jellyfish, Karen Plankton     1  0.17
# 1    French Narrator, Sea urchins, SpongeBob Square...     1  0.17
# 2    SpongeBob SquarePants, Squidward Tentacles, Re...     1  0.17
# 3    SpongeBob SquarePants, Jellyfish, Lavender jel...     1  0.17
# 4    SpongeBob SquarePants, Scallop, Squidward Tent...     1  0.17
# ..                                                 ...   ...   ...
# 578  Nematodes, Gary the Snail, SpongeBob SquarePan...     1  0.17
# 579  Baby fish, Barnacle Boy, Clam Head Candy Cad, ...     1  0.17
# 580  SpongeBob SquarePants, Squidward Tentacles, Bu...     1  0.17
# 581  French Narrator, SpongeBob SquarePants, Mrs. P...     1  0.17
# 582  French Narrator, Jellyfish, jellyfish, SpongeB...     1  0.17
#
# [583 rows x 3 columns]
# A coluna 'characters' possui apenas valores únicos.
#
# Análise da coluna 'title'
#                                  title  Soma     %
# 0    Snow Yellow and the Seven Jellies     1  0.17
# 1                          Help Wanted     1  0.17
# 2                          Reef Blower     1  0.17
# 3                  Tea at the Treedome     1  0.17
# 4                          Bubblestand     1  0.17
# ..                                 ...   ...   ...
# 578               Home Sweet Pineapple     1  0.17
# 579       Mermaid Man and Barnacle Boy     1  0.17
# 580                            Pickles     1  0.17
# 581                       Hall Monitor     1  0.17
# 582                      Jellyfish Jam     1  0.17
#
# [583 rows x 3 columns]
# A coluna 'title' possui apenas valores únicos.
