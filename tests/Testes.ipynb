# %%
# Para importar o DataQuality
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("Testes.ipynb"), '..')))

# Importando Classe DataQuality
from DataQuality import DataQuality

# %%
x = DataQuality("../data/Forbes_Richest_Atheletes_1990_2020.csv")

# %%
x.df
# Out:
#      S.NO               Name Nationality  Current Rank Previous Year Rank  \
# 0       1         Mike Tyson         USA             1                NaN
# 1       2     Buster Douglas         USA             2                NaN
# 2       3  Sugar Ray Leonard         USA             3                NaN
# 3       4       Ayrton Senna      Brazil             4                NaN
# 4       5        Alain Prost      France             5                NaN
# ..    ...                ...         ...           ...                ...
# 296   297      Stephen Curry         USA             6                  9
# 297   298       Kevin Durant         USA             7                 10
# 298   299        Tiger Woods         USA             8                 11
# 299   300       Kirk Cousins         USA             9               >100
# 300   301       Carson Wentz         USA            10               >100
#
#                  Sport  Year  earnings ($ million)
# 0               boxing  1990                  28.6
# 1               boxing  1990                  26.0
# 2               boxing  1990                  13.0
# 3          auto racing  1990                  10.0
# 4          auto racing  1990                   9.0
# ..                 ...   ...                   ...
# 296         Basketball  2020                  74.4
# 297         Basketball  2020                  63.9
# 298               Golf  2020                  62.3
# 299  American Football  2020                  60.5
# 300  American Football  2020                  59.1
#
# [301 rows x 8 columns]

# %%
x.lista_numericas
# Out:
# ['S.NO', 'Current Rank', 'Year', 'earnings ($ million)']

# %%
x.lista_categoricas
# Out:
# ['Name', 'Nationality', 'Previous Year Rank', 'Sport']

# %%
x.informacoes()
# Out:
# Informações Gerais:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   S.NO                  301 non-null    int64
#  1   Name                  301 non-null    object
#  2   Nationality           301 non-null    object
#  3   Current Rank          301 non-null    int64
#  4   Previous Year Rank    277 non-null    object
#  5   Sport                 301 non-null    object
#  6   Year                  301 non-null    int64
#  7   earnings ($ million)  301 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 18.9+ KB

# %%
x.df.shape
# Out:
# (301, 8)

# %%
x.contagem_nulos()
# Out:
#                       Nulos Soma  Nulos %
# S.NO                           0     0.00
# Name                           0     0.00
# Nationality                    0     0.00
# Current Rank                   0     0.00
# Previous Year Rank            24     7.97
# Sport                          0     0.00
# Year                           0     0.00
# earnings ($ million)           0     0.00

# %%
x.contagem_unicos()
# Out:
#                       Unicos Soma  Unicos %
# S.NO                          301    100.00
# Name                           82     27.24
# Nationality                    22      7.31
# Current Rank                   10      3.32
# Previous Year Rank             36     11.96
# Sport                          29      9.63
# Year                           30      9.97
# earnings ($ million)          198     65.78

# %%
x.descricao_numerica()
# Out:
#              S.NO  Current Rank         Year  earnings ($ million)
# count  301.000000    301.000000   301.000000            301.000000
# mean   151.000000      5.448505  2005.122924             45.516279
# std     87.035433      2.850995     9.063563             33.525337
# min      1.000000      1.000000  1990.000000              8.100000
# 25%     76.000000      3.000000  1997.000000             24.000000
# 50%    151.000000      5.000000  2005.000000             39.000000
# 75%    226.000000      8.000000  2013.000000             59.400000
# max    301.000000     10.000000  2020.000000            300.000000

# %%
x.descricao_categorica()
# Out:
#                   Name Nationality Previous Year Rank       Sport
# count              301         301                277         301
# unique              82          22                 36          29
# top     Michael Jordan         USA                >10  Basketball
# freq                19         206                 36          54

# %%
x.descricao_personalizada(["S.NO", "Current Rank"])
# Out:
#              S.NO  Current Rank
# count  301.000000    301.000000
# mean   151.000000      5.448505
# std     87.035433      2.850995
# min      1.000000      1.000000
# 25%     76.000000      3.000000
# 50%    151.000000      5.000000
# 75%    226.000000      8.000000
# max    301.000000     10.000000

# %%
x.descricao_personalizada(["Name", "Nationality"])
# Out:
#                   Name Nationality
# count              301         301
# unique              82          22
# top     Michael Jordan         USA
# freq                19         206

# %%
a, b = x.descricao_personalizada(["S.NO", "Current Rank", "Name", "Nationality"])

# %%
a
# Out:
#              S.NO  Current Rank
# count  301.000000    301.000000
# mean   151.000000      5.448505
# std     87.035433      2.850995
# min      1.000000      1.000000
# 25%     76.000000      3.000000
# 50%    151.000000      5.000000
# 75%    226.000000      8.000000
# max    301.000000     10.000000

# %%
b
# Out:
#                   Name Nationality
# count              301         301
# unique              82          22
# top     Michael Jordan         USA
# freq                19         206

# %%
dfs_categ = x.contagem_categorica()

for i in dfs_categ:
    display(i)
# Out:
#                   Name  Soma     %
# 0       Michael Jordan    19  6.31
# 1          Tiger Woods    19  6.31
# 2          Kobe Bryant    14  4.65
# 3   Michael Schumacher    13  4.32
# 4         LeBron James    13  4.32
# ..                 ...   ...   ...
# 77      Canelo Alvarez     1  0.33
# 78      Russell Wilson     1  0.33
# 79        Aaron Rogers     1  0.33
# 80        Kirk Cousins     1  0.33
# 81        Carson Wentz     1  0.33
#
# [82 rows x 3 columns]
#          Nationality  Soma      %
# 0                USA   206  68.44
# 1                 UK    13   4.32
# 2            Germany    13   4.32
# 3        Switzerland    12   3.99
# 4           Portugal    10   3.32
# 5             Brazil     9   2.99
# 6          Argentina     9   2.99
# 7             Canada     6   1.99
# 8              Italy     4   1.33
# 9             France     3   1.00
# 10       Philippines     3   1.00
# 11           Finland     3   1.00
# 12         Australia     1   0.33
# 13            Russia     1   0.33
# 14           Austria     1   0.33
# 15         Dominican     1   0.33
# 16          Filipino     1   0.33
# 17             Spain     1   0.33
# 18            Serbia     1   0.33
# 19  Northern Ireland     1   0.33
# 20           Ireland     1   0.33
# 21            Mexico     1   0.33
#    Previous Year Rank  Soma      %
# 0                 >10    36  11.96
# 1                   1    25   8.31
# 2                   5    21   6.98
# 3                   3    21   6.98
# 4                   2    20   6.64
# 5                   6    18   5.98
# 6                   4    17   5.65
# 7                   7    17   5.65
# 8                   8    14   4.65
# 9                   9    13   4.32
# 10                 10     8   2.66
# 11                >40     6   1.99
# 12                 11     6   1.99
# 13               >100     6   1.99
# 14         not ranked     4   1.33
# 15                 12     4   1.33
# 16                >20     4   1.33
# 17                 13     4   1.33
# 18                 19     3   1.00
# 19                 17     3   1.00
# 20                 20     3   1.00
# 21                  ?     3   1.00
# 22                >30     2   0.66
# 23                 30     2   0.66
# 24                 24     2   0.66
# 25                 ??     2   0.66
# 26                 15     2   0.66
# 27                 14     2   0.66
# 28                 18     2   0.66
# 29                 40     1   0.33
# 30                 22     1   0.33
# 31                 38     1   0.33
# 32               none     1   0.33
# 33                 26     1   0.33
# 34                >14     1   0.33
# 35                 21     1   0.33
#                            Sport  Soma      %
# 0                     Basketball    54  17.94
# 1                         Boxing    29   9.63
# 2                     basketball    27   8.97
# 3                           Golf    24   7.97
# 4                         Soccer    22   7.31
# 5                           golf    20   6.64
# 6                         Tennis    18   5.98
# 7              American Football    17   5.65
# 8                         boxing    17   5.65
# 9                         soccer    11   3.65
# 10                   Auto Racing    10   3.32
# 11                     F1 racing     8   2.66
# 12                   auto racing     7   2.33
# 13                        tennis     5   1.66
# 14                F1 Motorsports     5   1.66
# 15                 motorcycle gp     4   1.33
# 16                           NFL     3   1.00
# 17                      baseball     3   1.00
# 18                        NASCAR     3   1.00
# 19                      Baseball     3   1.00
# 20                    Ice Hockey     2   0.66
# 21          Auto Racing (Nascar)     2   0.66
# 22                   Auto racing     1   0.33
# 23                           NBA     1   0.33
# 24  American Football / Baseball     1   0.33
# 25                        Hockey     1   0.33
# 26                    ice hockey     1   0.33
# 27                       cycling     1   0.33
# 28                           MMA     1   0.33

# %%
dfs_num = x.contagem_numerica()

for i in dfs_num:
    display(i)
# Out:
#      S.NO  Soma     %
# 0     301     1  0.33
# 1       1     1  0.33
# 2       2     1  0.33
# 3       3     1  0.33
# 4       4     1  0.33
# ..    ...   ...   ...
# 296    17     1  0.33
# 297    18     1  0.33
# 298    19     1  0.33
# 299    20     1  0.33
# 300    21     1  0.33
#
# [301 rows x 3 columns]
#    Current Rank  Soma      %
# 0             9    34  11.30
# 1             2    32  10.63
# 2             5    32  10.63
# 3             6    32  10.63
# 4             1    30   9.97
# 5             3    30   9.97
# 6             8    30   9.97
# 7             4    28   9.30
# 8             7    28   9.30
# 9            10    25   8.31
#     Year  Soma     %
# 0   2002    11  3.65
# 1   1990    10  3.32
# 2   1992    10  3.32
# 3   1993    10  3.32
# 4   1994    10  3.32
# 5   1991    10  3.32
# 6   1995    10  3.32
# 7   1996    10  3.32
# 8   1998    10  3.32
# 9   1997    10  3.32
# 10  1999    10  3.32
# 11  2000    10  3.32
# 12  2003    10  3.32
# 13  2004    10  3.32
# 14  2005    10  3.32
# 15  2006    10  3.32
# 16  2007    10  3.32
# 17  2008    10  3.32
# 18  2009    10  3.32
# 19  2010    10  3.32
# 20  2011    10  3.32
# 21  2012    10  3.32
# 22  2013    10  3.32
# 23  2014    10  3.32
# 24  2015    10  3.32
# 25  2016    10  3.32
# 26  2017    10  3.32
# 27  2018    10  3.32
# 28  2019    10  3.32
# 29  2020    10  3.32
#      earnings ($ million)  Soma     %
# 0                    40.0     7  2.33
# 1                    35.0     7  2.33
# 2                    28.0     6  1.99
# 3                    23.0     6  1.99
# 4                    33.0     5  1.66
# ..                    ...   ...   ...
# 193                  88.2     1  0.33
# 194                  74.4     1  0.33
# 195                  63.9     1  0.33
# 196                  62.3     1  0.33
# 197                  59.1     1  0.33
#
# [198 rows x 3 columns]

# %%
x.grafico_dist_categ()
# Out:
# Distribuição das Colunas Categóricas:

# %%
x.grafico_dist_num()
# Out:
# Distribuição das Colunas Numéricas:

# %%
x.grafico_diagrama_caixa()
# Out:
# Boxplot das Colunas Numéricas:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 x.grafico_diagrama_caixa()
#
# File c:\Users\nicol\OneDrive\Estudos\AdaTech\Santander Coders 2024\Projeto_04.03_DataViz\DataQuality.py:138, in DataQuality.grafico_diagrama_caixa(self)
#     136     count_cores = 0
#     137 sns.set_style(plot_style)
# --> 138 sns.boxplot(self.df[coluna], color = color_palette[count_cores])
#     139 plt.title(f"Boxplot de {coluna}")
#     140 plt.show()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
x.matriz_correlacao()

# %%
# x.grafico_relacao_pares()

# %%
x.relatorio()
