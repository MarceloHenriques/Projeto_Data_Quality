# %%
# Para importar o DataQuality
import sys
import os
csv = "Forbes_Richest_Atheletes_1990_2020.csv"
sys.path.append(os.path.abspath(os.path.join(os.path.dirname(f"{csv}.ipynb"), '..')))

# Importando Classe DataQuality
from DataQuality import DataQuality

# %%
x = DataQuality(f"../data/{csv}")

# %%
x.relatorio()
# Out:
# ANÁLISE DO CONJUNTO DE DADOS DO DATAFRAME ../data/Forbes_Richest_Atheletes_1990_2020.csv.
#
# INFORMAÇÕES GERAIS:
#
# Tamanho do Dataset:
# 301 linhas;
# 8 colunas;
#                 Colunas Tipo de Dados  Nulos Soma  Nulos %  Unicos Soma  \
# 0                  S.NO         int64           0     0.00          301
# 1                  Name        object           0     0.00           82
# 2           Nationality        object           0     0.00           22
# 3          Current Rank         int64           0     0.00           10
# 4    Previous Year Rank        object          24     7.97           36
# 5                 Sport        object           0     0.00           29
# 6                  Year         int64           0     0.00           30
# 7  earnings ($ million)       float64           0     0.00          198
#
#    Unicos %
# 0    100.00
# 1     27.24
# 2      7.31
# 3      3.32
# 4     11.96
# 5      9.63
# 6      9.97
# 7     65.78
# Exibindo as 5 primeiras linhas:
# ...
